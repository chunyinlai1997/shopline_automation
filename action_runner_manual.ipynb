# %%
#must run, intialize bs object
import browser
bs = browser.Action()

# %%
#optional
#force closing pre order by keywords
bs.close_preorder_by_keywords()

# %%
#optional
#check if any close pre order setting is missing
bs.find_missing_allow_oversale()
# Out:
# Login Shopline Admin successful
# 48
#
# Sagami 相模 六段緊第二代 乳膠安全套
#
# Sagami 相模原創 0.01 大碼 10 片裝 PU 安全套
#
# Sagami 相模 凸點一段波 乳膠安全套 5片裝
#
# Sagami 相模原創 0.01 10 片裝 PU 安全套
#
# Sagami 相模原創 0.01 12 片裝 PU 安全套
#
# Sagami 相模 真空貼身 乳膠安全套 10 片裝
#
# Sagami 相模原創 0.01 極潤 12 片裝 PU 安全套
#
# Sagami 相模 0.09 凸點 乳膠安全套 10片裝
#
# Sagami 相模 99%水潤滑 水性潤滑劑 60g
#
# Sagami 相模原創 0.01 PU安全套 1片裝
#
# Sagami 相模 Miracle Fit 乳膠安全套 1片裝
#
# Sagami Value 1000 特薄乳膠安全套 (12片裝）
#
# Sagami 相模原創 潤滑凝膠 水性潤滑劑 60g
#
# Sagami 相模原創 0.01 20 片裝 PU 安全套
#
# Sagami 相模 凸點一段波 乳膠安全套 10片裝
#
# Sagami 相模 Miracle Fit 奇妙貼身51mm 乳膠安全套 10片裝
#
# Sagami 相模 ALL YOU NEED IS LOVE 費洛蒙噴霧 30ml
#
# Sagami Value 1500 防脫落乳膠安全套 (12片裝)
#
# Sagami 相模原創 0.01 5 片裝 PU 安全套
#
# Sagami 相模原創 0.02 大碼 (第二代) 58mm 1 片裝 PU 安全套
#
# Sagami 相模原創 0.02 大碼 (第二代) 58mm 3 片裝 PU 安全套
#
# Sagami 相模究極力量增強式 53/44mm 3 片裝 乳膠安全套
#
# Sagami 相模究極 持久點點 乳膠安全套 15片裝
#
# Sagami 相模原創 0.02 快閃 (第二代) 5片裝 PU 安全套
#
# Sagami 相模粒粒波子汽水 5 片裝 乳膠安全套
#
# Sagami 相模究極纖薄式(第二代) 36 片裝 乳膠安全套
#
# ...
